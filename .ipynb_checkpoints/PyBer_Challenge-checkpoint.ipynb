# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "C:/Users/Lakenia/Desktop/PyBer_Analysis/PyBer_Analysis/Resources/city_data.csv"
ride_data_to_load = "C:/Users/Lakenia/Desktop/PyBer_Analysis/PyBer_Analysis/Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

pyber_data_df["date"] = pd.to_datetime(pyber_data_df["date"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                date   fare        ride_id  driver_count  \
# 0  Lake Jonathanshire 2019-01-14 10:14:00  13.83  5740000000000             5
# 1  South Michelleport 2019-03-04 18:24:00  30.24  2340000000000            72
# 2  Port Samanthamouth 2019-02-24 04:29:00  33.44  2010000000000            57
# 3          Rodneyfort 2019-02-10 23:22:00  23.44  5150000000000            34
# 4          South Jack 2019-03-06 04:28:00  34.58  3910000000000            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
urban_ride_count = urban_cities_df.groupby(["type"]).count()["ride_id"]

urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]

# %%
# 2. Get the total drivers for each city type
urban_driver_sum = urban_cities_df.groupby(["type"]).sum()["driver_count"]
suburban_driver_sum = suburban_cities_df.groupby(["type"]).sum()["driver_count"]
rural_driver_sum = rural_cities_df.groupby(["type"]).sum()["driver_count"]

urban_driver_sum
# Out:
# type
# Urban    59602
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
urban_fare_sum = urban_cities_df.groupby(["city"]).sum()["fare"]
suburban_fare_sum = urban_cities_df.groupby(["city"]).sum()["fare"]
rural_fare_sum = urban_cities_df.groupby(["city"]).sum()["fare"]

# %%
#  4. Get the average fare per ride for each city type. 
total_rides_by_type = pyber_data_df.groupby(["type"]).count()["ride_id"]

total_fares_by_type = pyber_data_df.groupby(["type"]).sum()["fare"]


average_fare_per_ride_by_type = total_fares_by_type / total_rides_by_type

average_fare_per_ride_by_type
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
total_drivers_by_type = city_data_df.groupby(["type"]).sum()["driver_count"]

average_fare_per_driver_by_type = total_fares_by_type / total_drivers_by_type

average_fare_per_driver_by_type
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.DataFrame(
          {"Total Rides": total_rides_by_type,
          "Total Drivers": total_drivers_by_type,
          "Total Fares": total_fares_by_type,
          "Average Fare per Ride": average_fare_per_ride_by_type,
          "Average Fare per Driver": average_fare_per_driver_by_type})
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df = pd.DataFrame(
          {"Total Rides": total_rides_by_type.map("{:,}".format),
          "Total Drivers": total_drivers_by_type.map("{:,}".format),
          "Total Fares": total_fares_by_type.map("${:,.2f}".format),
          "Average Fare per Ride": average_fare_per_ride_by_type.map("${:,.2f}".format),
          "Average Fare per Driver": average_fare_per_driver_by_type.map("${:,.2f}".format)})
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# type
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# type
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame

pyber_data_df.head()
# Out:
#                  city                date   fare        ride_id  driver_count  \
# 0  Lake Jonathanshire 2019-01-14 10:14:00  13.83  5740000000000             5
# 1  South Michelleport 2019-03-04 18:24:00  30.24  2340000000000            72
# 2  Port Samanthamouth 2019-02-24 04:29:00  33.44  2010000000000            57
# 3          Rodneyfort 2019-02-10 23:22:00  23.44  5150000000000            34
# 4          South Jack 2019-03-06 04:28:00  34.58  3910000000000            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
sum_of_fares_by_date_city_type = pyber_data_df.groupby(["type","date"]).sum()["fare"]

sum_of_fares_by_date_city_type
# Out:
# type   date
# Rural  2019-01-01 09:45:00    43.69
#        2019-01-02 11:18:00    52.12
#        2019-01-03 19:51:00    19.90
#        2019-01-04 03:31:00    24.88
#        2019-01-06 07:38:00    47.33
#                               ...
# Urban  2019-05-08 04:20:00    21.99
#        2019-05-08 04:39:00    18.45
#        2019-05-08 07:29:00    18.55
#        2019-05-08 11:38:00    19.77
#        2019-05-08 13:10:00    18.04
# Name: fare, Length: 2364, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
sum_of_fares_by_date_city_type = sum_of_fares_by_date_city_type.reset_index()




sum_of_fares_by_date_city_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2364 entries, 0 to 2363
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type    2364 non-null   object
#  1   date    2364 non-null   datetime64[ns]
#  2   fare    2364 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 55.5+ KB

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
type_pivot = pd.pivot_table(sum_of_fares_by_date_city_type, values=['fare'], index=['date'], columns='type')
type_pivot
# Out:
#                      fare
# type                Rural Suburban  Urban
# date
# 2019-01-01 00:08:00   NaN      NaN  37.91
# 2019-01-01 00:46:00   NaN    47.74    NaN
# 2019-01-01 02:07:00   NaN    24.07    NaN
# 2019-01-01 03:46:00   NaN      NaN   7.57
# 2019-01-01 05:23:00   NaN      NaN  10.75
# ...                   ...      ...    ...
# 2019-05-08 04:20:00   NaN      NaN  21.99
# 2019-05-08 04:39:00   NaN      NaN  18.45
# 2019-05-08 07:29:00   NaN      NaN  18.55
# 2019-05-08 11:38:00   NaN      NaN  19.77
# 2019-05-08 13:10:00   NaN      NaN  18.04
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

pivot_sum_of_fares_by_date_city_type_rev = type_pivot.loc['1/1/2019':'4/29/2019']
pivot_sum_of_fares_by_date_city_type_rev
# Out:
#                      fare
# type                Rural Suburban  Urban
# date
# 2019-01-01 00:08:00   NaN      NaN  37.91
# 2019-01-01 00:46:00   NaN    47.74    NaN
# 2019-01-01 02:07:00   NaN    24.07    NaN
# 2019-01-01 03:46:00   NaN      NaN   7.57
# 2019-01-01 05:23:00   NaN      NaN  10.75
# ...                   ...      ...    ...
# 2019-04-29 20:54:00   NaN      NaN  28.41
# 2019-04-29 21:20:00   NaN      NaN  13.59
# 2019-04-29 22:08:00   NaN    25.75    NaN
# 2019-04-29 23:05:00   NaN      NaN  14.59
# 2019-04-29 23:10:00   NaN    29.39    NaN
#
# [2204 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
pivot_sum_of_fares_by_date_city_type_rev.index = pd.to_datetime(pivot_sum_of_fares_by_date_city_type_rev.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
pivot_sum_of_fares_by_date_city_type_rev
# Out:
#                      fare
# type                Rural Suburban  Urban
# date
# 2019-01-01 00:08:00   NaN      NaN  37.91
# 2019-01-01 00:46:00   NaN    47.74    NaN
# 2019-01-01 02:07:00   NaN    24.07    NaN
# 2019-01-01 03:46:00   NaN      NaN   7.57
# 2019-01-01 05:23:00   NaN      NaN  10.75
# ...                   ...      ...    ...
# 2019-04-29 20:54:00   NaN      NaN  28.41
# 2019-04-29 21:20:00   NaN      NaN  13.59
# 2019-04-29 22:08:00   NaN    25.75    NaN
# 2019-04-29 23:05:00   NaN      NaN  14.59
# 2019-04-29 23:10:00   NaN    29.39    NaN
#
# [2204 rows x 3 columns]

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
pivot_sum_of_fares_by_date_city_type_weekly = pivot_sum_of_fares_by_date_city_type_rev.resample('W').sum()
pivot_sum_of_fares_by_date_city_type_rev
# Out:
#               fare
# type         Rural Suburban    Urban
# date
# 2019-01-06  187.92   721.60  1661.68
# 2019-01-13   67.65  1105.13  2050.43
# 2019-01-20  306.00  1218.20  1939.02
# 2019-01-27  179.69  1203.28  2129.51
# 2019-02-03  333.08  1042.79  2086.94
# 2019-02-10  115.80   974.34  2162.64
# 2019-02-17   95.82  1045.50  2235.07
# 2019-02-24  419.06  1412.74  2466.29
# 2019-03-03  175.14   858.46  2218.20
# 2019-03-10  303.94   925.27  2470.93
# 2019-03-17  163.39   906.20  2044.42
# 2019-03-24  189.76  1122.20  2368.37
# 2019-03-31  199.42  1045.06  1942.77
# 2019-04-07  501.24  1010.73  2356.70
# 2019-04-14  269.79   784.82  2390.72
# 2019-04-21  214.14  1149.27  2303.80
# 2019-04-28  191.85  1357.75  2238.29
# 2019-05-05   67.60   167.92   342.63

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function.


# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
ax = pivot_sum_of_fares_by_date_city_type_weekly.plot(figsize=(20, 7.5))
# Create titles, axis labels, and legend
ax.set_title("Total Fare by City Type")
ax.set_ylabel("Fare ($USD)")
ax.set_xlabel("Month")

plt.savefig("C:/Users/Lakenia/Desktop/PyBer_Analysis/PyBer_Analysis/Analysis/CityType.png")

plt.show()
